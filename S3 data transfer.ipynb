# %%
import boto3

# %%
from boto.s3.connection import S3Connection
from multiprocessing.pool import ThreadPool
from pathlib import Path

# %%
import glob
files = glob.glob(r'C:\Users\roshn\Documents\DataAnalytics\Springboard\CV_Fashion_dataset\train\train\image_train\*.jpg')

# %%
texts = glob.glob(r'C:\Users\roshn\Documents\DataAnalytics\Springboard\CV_Fashion_dataset\train\train\YOLO_train\*.txt')

# %%
files[100000]
# Out:
# 'C:\\Users\\roshn\\Documents\\DataAnalytics\\Springboard\\CV_Fashion_dataset\\train\\train\\image_train\\100001.jpg'

# %%
import pandas as pd
uploaded=[]
#folder = 'train_data/'
def upload(myfile):
        key = Path(myfile).stem+'.jpg'
        uploaded.append(myfile)        
        
        if int(Path(myfile).stem)%2000 ==0:
            print('Uploading'+key)
            progress = pd.DataFrame.from_dict({'uploaded':uploaded})
            progress.to_csv('Train_image_progress_2.csv')            
        
        s3 = boto3.client('s3')
        s3.upload_file(myfile,'roshnicvdata',folder+key)

# %%
folder = 'train_data/'
pool = ThreadPool(processes=20)
pool.map(upload, remaining)
# Out:
# 23.6 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import pandas as pd

data = pd.read_csv('Train_image_progress_1.csv')
remaining = list(set(files[100000:])-set(data.uploaded))
len(remaining)
# Out:
# 24049

# %%
uploaded=[]

def upload_txt(myfile):
        key = Path(myfile).stem+'.txt'
        uploaded.append(myfile)
        if int(Path(myfile).stem)%2000 ==0:
            print('Uploading'+key)
        
        s3 = boto3.client('s3')
        s3.upload_file(myfile,'roshnicvdata',folder+key)

# %%
folder = 'train_data/'
pool = ThreadPool(processes=20)
pool.map(upload_txt, texts)

# %%
pool = ThreadPool(processes=20)
pool.map(upload_txt, remaining)

# %%
remaining = list(set(remaining)-set(uploaded))

# %%
len(uploaded)
# Out:
# 31971

# %%
len(remaining)
# Out:
# 0

# %% [markdown]
# #### Loading Validation Data

# %%
folder = 'val_data/'
val_files = glob.glob(r'C:\Users\roshn\Documents\DataAnalytics\Springboard\CV_Fashion_dataset\validation\image\*.jpg')
val_txts = glob.glob(r'C:\Users\roshn\Documents\DataAnalytics\Springboard\CV_Fashion_dataset\validation\YOLO\*.txt')

# %%
len(uploaded)
# Out:
# 32153

# %%
pool = ThreadPool(processes=20)
pool.map(upload_txt, val_txts)
# Out:
# Uploading008000.txt
# Uploading006000.txt
# Uploading004000.txt
# Uploading002000.txt
# Uploading014000.txt
# Uploading016000.txt
# Uploading012000.txt
# Uploading010000.txt
# Uploading020000.txt
# Uploading022000.txt
# Uploading018000.txt
# Uploading024000.txt
# Uploading030000.txt
# Uploading032000.txt
# Uploading028000.txt
# Uploading026000.txt
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
uploaded = []
pool = ThreadPool(processes=20)
pool.map(upload, val_files)
# Out:
# Uploading008000.jpg
# Uploading006000.jpg
# Uploading004000.jpg
# Uploading002000.jpg
# Uploading010000.jpg
# Uploading014000.jpg
# Uploading016000.jpg
# Uploading012000.jpg
# Uploading018000.jpg
# Uploading020000.jpg
# Uploading022000.jpg
# Uploading024000.jpg
# Uploading026000.jpg
# Uploading028000.jpg
# Uploading030000.jpg
# Uploading032000.jpg
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
